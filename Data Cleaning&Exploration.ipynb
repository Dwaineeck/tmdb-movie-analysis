# %%
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical operations
import matplotlib.pyplot as plt  # For plotting graphs
import seaborn as sns  # For statistical data visualization

# %%
#LoadDataset
df = pd.read_csv(r'D:\thenumerix\Data Cleaning & Exploration\TMDB_movie_dataset_v11.csv')

# %%
#ExploreData
df.head()  # View the first 5 rows of the dataset
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
df.info()  # Overview of the dataset, including data types and non-null counts
df.describe()  # Summary statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1051223 entries, 0 to 1051222
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1051223 non-null  int64
#  1   title                 1051211 non-null  object
#  2   vote_average          1051223 non-null  float64
#  3   vote_count            1051223 non-null  int64
#  4   status                1051223 non-null  object
#  5   release_date          911420 non-null   object
#  6   revenue               1051223 non-null  int64
#  7   runtime               1051223 non-null  int64
#  8   adult                 1051223 non-null  bool
#  9   backdrop_path         289603 non-null   object
#  10  budget                1051223 non-null  int64
#  11  homepage              113459 non-null   object
#  12  imdb_id               583746 non-null   object
#  13  original_language     1051223 non-null  object
# ...

# %%
df.isnull().sum()  # Count of missing values in each column
# Out:
# id                           0
# title                       12
# vote_average                 0
# vote_count                   0
# status                       0
# release_date            139803
# revenue                      0
# runtime                      0
# adult                        0
# backdrop_path           761620
# budget                       0
# homepage                937764
# imdb_id                 467477
# original_language            0
# original_title              12
# overview                195822
# popularity                   0
# poster_path             306224
# tagline                 901157
# genres                  399931
# production_companies    560798
# production_countries    441599
# spoken_languages        427385
# keywords                754109
# dtype: int64

# %%
df['budget'] = df['budget'].fillna(df['budget'].median())  # Fill missing budget values with the median
df = df.dropna(subset=['revenue'])  # Drop rows where the revenue column is missing

# %%
#VISUALIZE KEY STATISTICS#

# %%
sns.histplot(df['budget'], bins=20)  # Histogram of the budget column
plt.show()  # Display the plot

# %%
#CORRELATION HEATMAP#

# %%
numeric_df = df.select_dtypes(include=[np.number])  # Select only numeric columns
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(numeric_df.corr(), annot=True)  # Heatmap of correlation matrix with annotations
plt.show()  # Display the plot

# %%
df = df.drop_duplicates(subset='title', keep='first')

# %%
# Data type conversion
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
# Feature engineering
df['profit'] = df['revenue'] - df['budget']
df['release_year'] = df['release_date'].dt.year

# %%
# Visualization: Histogram of the budget
sns.histplot(df['budget'], bins=20)
plt.title('Budget Distribution')
plt.xlabel('Budget')
plt.ylabel('Frequency')
plt.show()

# %%
#Visualization: Correlation heatmap (Numeric columns only)
numeric_df = df.select_dtypes(include=[np.number])  # Select only numeric columns
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
